# %% [markdown]
# # Make Panel Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

mydir = os.getcwd()

FY09 = pd.read_csv(os.path.join(mydir,'CSV', 'FY09.csv'),index_col=0)
FY10 = pd.read_csv(os.path.join(mydir,'CSV', 'FY10.csv'),index_col=0)
FY11 = pd.read_csv(os.path.join(mydir,'CSV', 'FY11.csv'),index_col=0)
FY12 = pd.read_csv(os.path.join(mydir,'CSV', 'FY12.csv'),index_col=0)
FY13 = pd.read_csv(os.path.join(mydir,'CSV', 'FY13.csv'),index_col=0)
FY14 = pd.read_csv(os.path.join(mydir,'CSV', 'FY14.csv'),index_col=0)
FY15 = pd.read_csv(os.path.join(mydir,'CSV', 'FY15.csv'),index_col=0)
FY16 = pd.read_csv(os.path.join(mydir,'CSV', 'FY16.csv'),index_col=0)

# %%
#cleaning
FY09 = FY09.dropna(axis=0, how='all')
FY10 = FY10.dropna(axis=0, how='all')
FY11 = FY11.dropna(axis=0, how='all')
FY12 = FY12.dropna(axis=0, how='all')
FY13 = FY13.dropna(axis=0, how='all')
FY14 = FY14.dropna(axis=0, how='all')
FY15 = FY15.dropna(axis=0, how='all')
FY16 = FY16.dropna(axis=0, how='all')

# %%
#construct full index of school codes
fullindex = np.union1d(FY09.index.values,FY10.index.values)
fullindex = np.union1d(fullindex,FY11.index.values)
fullindex = np.union1d(fullindex,FY12.index.values)
fullindex = np.union1d(fullindex,FY13.index.values)
fullindex = np.union1d(fullindex,FY14.index.values)
fullindex = np.union1d(fullindex,FY15.index.values)
fullindex = np.union1d(fullindex,FY16.index.values)

# %%
#construct multi-year dataset
iterables = [[2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016], fullindex]
allyears = pd.MultiIndex.from_product(iterables, names=['Year', 'SchoolID'])

fullset = pd.DataFrame(index=allyears, columns=FY16.columns)

# %%
fullset
# Out:
#               School Total White AfricanAmerican  API NativeAmericanAlaskan  \
# Year SchoolID
# 2009 400008.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400009.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400010.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400011.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400012.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400013.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400015.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400017.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400018.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400019.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400020.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400021.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400022.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400023.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400024.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400025.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400026.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400027.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400028.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400029.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400030.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400031.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400032.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400033.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400034.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400035.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400036.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400037.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400038.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      400039.0    NaN   NaN   NaN             NaN  NaN                   NaN
# ...              ...   ...   ...             ...  ...                   ...
# 2016 610548.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610549.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610550.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610551.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610552.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610553.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610554.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610555.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610556.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610557.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610558.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610559.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610561.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610563.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610564.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610565.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610566.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610567.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610568.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610569.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610570.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610571.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610572.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610573.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610574.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610580.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610581.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610582.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610584.0    NaN   NaN   NaN             NaN  NaN                   NaN
#      610585.0    NaN   NaN   NaN             NaN  NaN                   NaN
#
#               Hispanic   MR Asian  HPR   NA
# Year SchoolID
# 2009 400008.0      NaN  NaN   NaN  NaN  NaN
#      400009.0      NaN  NaN   NaN  NaN  NaN
#      400010.0      NaN  NaN   NaN  NaN  NaN
#      400011.0      NaN  NaN   NaN  NaN  NaN
#      400012.0      NaN  NaN   NaN  NaN  NaN
#      400013.0      NaN  NaN   NaN  NaN  NaN
#      400015.0      NaN  NaN   NaN  NaN  NaN
#      400017.0      NaN  NaN   NaN  NaN  NaN
